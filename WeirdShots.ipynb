# %%
# %pylab inline
import toolbox as tb
pylab.rcParams['figure.figsize'] = (15.0, 10.0)
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # Weird Shots
# ## Tuesday (calibration)

# %%
tb.plotScope(22,3,22)
# very strong in UB2, nothing in other (adjacent) detectors, but does seem to be noise issues...
# effect of coupling power supplies together?

# %%
tb.plotScope(22,3,44)
# Not really all _that_ weird...
# interesting time structure, strong pulses in UB2 not seen in others.

# %%
tb.plotScope(24,3,103)
# light leak, especially in UB1.  annoying.  Appears a _lot_ in the later shots.

# %%
tb.plotScope(24,3,175)
# influence of of power supply coupling in channel 4?

# %%
reload(tb)
# Out:
# <module 'toolbox' from 'toolbox.py'>
